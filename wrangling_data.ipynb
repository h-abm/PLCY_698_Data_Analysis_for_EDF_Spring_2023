# %%
import pandas as pd
import datascience
import numpy as np
import matplotlib.pyplot as plt

# %%
edf_data = pd.read_csv('EDF_Database.csv')
edf_data.head(6)
# Out:
#    Place FIPS  Unincorporated, Non-Place FIPS Geography Name County FIPS  \
# 0   3700160.0                             NaN  Aberdeen town         125
# 1         NaN                             NaN            NaN         NaN
# 2   3700440.0                             NaN    Advance CDP          59
# 3         NaN                             NaN            NaN         NaN
# 4   3700500.0                             NaN   Ahoskie town          91
# 5         NaN                             NaN            NaN         NaN
#
#   County Name Total Population SE:A00002. Population Density (Per Sq. Mile)  \
# 0       Moore            7,862
# 1         NaN              NaN
# 2       Davie            1,135
# 3         NaN              NaN
# 4    Hertford            4,819
# 5         NaN              NaN
#
#   Population Density (Per Sq. Mile)  Area (Land) SE:A01001. Age  ...  \
# 0                             774.8        10.15                 ...
# ...

# %%
# Count total values in Place FIPS
edf_data['Place FIPS'].count()
# Out:
# 776

# %%
edf_data['Place FIPS'].isnull().count()
# Out:
# 3618

# %%
len(edf_data)
# Out:
# 3618

# %%
edf_data_2 = edf_data[edf_data['Place FIPS'].notnull()]
len(edf_data_2)
# Out:
# 776

# %%
edf_data_2
# Out:
#       Place FIPS  Unincorporated, Non-Place FIPS      Geography Name  \
# 0      3700160.0                             NaN       Aberdeen town
# 2      3700440.0                             NaN         Advance CDP
# 4      3700500.0                             NaN        Ahoskie town
# 6      3700640.0                             NaN    Alamance village
# 8      3700680.0                             NaN      Albemarle city
# ...          ...                             ...                 ...
# 1542   3775880.0                             NaN  Yadkin College CDP
# 1544   3775960.0                             NaN    Yadkinville town
# 1546   3776000.0                             NaN    Yanceyville town
# 1548   3776200.0                             NaN    Youngsville town
# 1550   3776220.0                             NaN        Zebulon town
#
#      County FIPS County Name Total Population  \
# 0            125       Moore            7,862
# ...

# %%
isinstance(edf_data_2['Place FIPS'][0], float)
# Out:
# True

# %%
edf_data_2.drop
# Out:
# <bound method DataFrame.drop of       Place FIPS  Unincorporated, Non-Place FIPS      Geography Name  \
# 0      3700160.0                             NaN       Aberdeen town
# 2      3700440.0                             NaN         Advance CDP
# 4      3700500.0                             NaN        Ahoskie town
# 6      3700640.0                             NaN    Alamance village
# 8      3700680.0                             NaN      Albemarle city
# ...          ...                             ...                 ...
# 1542   3775880.0                             NaN  Yadkin College CDP
# 1544   3775960.0                             NaN    Yadkinville town
# 1546   3776000.0                             NaN    Yanceyville town
# 1548   3776200.0                             NaN    Youngsville town
# 1550   3776220.0                             NaN        Zebulon town
#
#      County FIPS County Name Total Population  \
# 0            125       Moore            7,862
# ...

# %% [markdown]
# Below I converted the pandas dataframe to a datascience table. This was done for techanical reasons because I like the datascience library better than pandas.

# %%
# convert pandas dataframe to datascience table
edf_data_3 = datascience.Table.from_df(edf_data_2)
edf_data_3
# Out:
# Place FIPS  | Unincorporated, Non-Place FIPS | Geography Name     | County FIPS | County Name | Total Population | SE:A00002. Population Density (Per Sq. Mile) | Population Density (Per Sq. Mile) | Area (Land) | SE:A01001. Age | Under 5 Years | 5 to 9 Years | 10 to 14 Years | 15 to 17 Years | 18 to 24 Years | 25 to 34 Years | 35 to 44 Years | 45 to 54 Years | 55 to 64 Years | 65 to 74 Years | 75 to 84 Years | 85 Years and Over | SE:A03001. Race | White Alone | Black or African American Alone | American Indian and Alaska Native Alone | Asian Alone | Native Hawaiian and Other Pacific Islander Alone | Some Other Race Alone | Two or More Races | SE:B04001. Hispanic or Latino  | Not Hispanic or Latino: | Hispanic or Latino | SE:A12001. Educational Attainment for Population 25 Years and Over | Population 25 Years and Over: | Less than High School | High School Graduate (Includes Equivalency) | Some College | Bachelor's Degree | Master's Degree | Professional School Degree | Doctorate Degre
# ...

# %%
edf_data_3.drop("SE:A00002. Population Density (Per Sq. Mile)", "")
# Out:
# Place FIPS  | Unincorporated, Non-Place FIPS | Geography Name     | County FIPS | County Name | Total Population | Population Density (Per Sq. Mile) | Area (Land) | SE:A01001. Age | Under 5 Years | 5 to 9 Years | 10 to 14 Years | 15 to 17 Years | 18 to 24 Years | 25 to 34 Years | 35 to 44 Years | 45 to 54 Years | 55 to 64 Years | 65 to 74 Years | 75 to 84 Years | 85 Years and Over | SE:A03001. Race | White Alone | Black or African American Alone | American Indian and Alaska Native Alone | Asian Alone | Native Hawaiian and Other Pacific Islander Alone | Some Other Race Alone | Two or More Races | SE:B04001. Hispanic or Latino  | Not Hispanic or Latino: | Hispanic or Latino | SE:A12001. Educational Attainment for Population 25 Years and Over | Population 25 Years and Over: | Less than High School | High School Graduate (Includes Equivalency) | Some College | Bachelor's Degree | Master's Degree | Professional School Degree | Doctorate Degree | SE:B12001. Educational Attainment for Popul
# ...

# %%
edf_data_3.drop("Unincorporated, Non-Place FIPS", "SE:A03001. Race", "SE:B04001. Hispanic or Latino", "SE:A12001. Educational Attainment for Population 25 Years and Over", "SE:B12001. Educational Attainment for Population 25 Years and Over (CollapsedVersion)")
# Out:
# Place FIPS  | Geography Name     | County FIPS | County Name | Total Population | SE:A00002. Population Density (Per Sq. Mile) | Population Density (Per Sq. Mile) | Area (Land) | SE:A01001. Age | Under 5 Years | 5 to 9 Years | 10 to 14 Years | 15 to 17 Years | 18 to 24 Years | 25 to 34 Years | 35 to 44 Years | 45 to 54 Years | 55 to 64 Years | 65 to 74 Years | 75 to 84 Years | 85 Years and Over | White Alone | Black or African American Alone | American Indian and Alaska Native Alone | Asian Alone | Native Hawaiian and Other Pacific Islander Alone | Some Other Race Alone | Two or More Races | SE:B04001. Hispanic or Latino  | Not Hispanic or Latino: | Hispanic or Latino | Population 25 Years and Over: | Less than High School | High School Graduate (Includes Equivalency) | Some College | Bachelor's Degree | Master's Degree | Professional School Degree | Doctorate Degree | SE:B12001. Educational Attainment for Population 25 Years and Over (Collapsed Version) | Population 25 Years and Ove
# ...

# %%
isinstance(edf_data_2['Total Population'][0], float)
# Out:
# False

# %%
edf_data_5 = edf_data_2["Total Population"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 edf_data_5 = edf_data_2["Total Population"].astype(float)
#
# File ~/miniconda3/envs/PLCY_698_DATA_ANALYSIS/lib/python3.10/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
# Save to csv
edf_data_2

# %%
edf_data_2.drop("Unincorporated, Non-Place FIPS", "SE:A03001. Race", "SE:B04001. Hispanic or Latino", "SE:A12001. Educational Attainment for Population 25 Years and Over", "SE:B12001. Educational Attainment for Population 25 Years and Over (CollapsedVersion)")

# %%
edf_data_3.drop("Unincorporated, Non-Place FIPS", "SE:A03001. Race", "SE:B04001. Hispanic or Latino", "SE:A12001. Educational Attainment for Population 25 Years and Over", "SE:B12001. Educational Attainment for Population 25 Years and Over (CollapsedVersion)")

# %%
print(type(edf_data_2['Total Population'][0])) # str needs to convert to a float

# %%
edf_data_2['Total Population'] = edf_data_2['Total Population'].astype(float)

# %%
# Remove commas from Total Population
edf_data_2['Total Population'] = edf_data_2['Total Population'].str.replace(',', '')

# %%
edf_data_2['Total Population'] = edf_data_2['Total Population'].astype(float)

# %% [markdown]
# Have to remove all commas from the Total Population column then you can convert it to a float.
# SAMPLE CODE:
#
# column_name = "CHANGE THIS"
# edf_data_2[column_name] = edf_data_2[column_name].str.replace(',', '')
# edf_data_2[column_name] = edf_data_2[column_name].astype(float)

# %%
def str_to_flt(column_name):
    edf_data_2[column_name] = edf_data_2[column_name].str.replace(',', '')
    edf_data_2[column_name] = edf_data_2[column_name].astype(float)
    print(type(edf_data_2[column_name][0]))

# %%
print(type(edf_data_2['Total Population'][0]))
# Out:
# <class 'str'>

# %% [markdown]
# Success! I was able to convert the Total Population column to a float.

# %%
edf_data_2.hist(column='Total Population')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 edf_data_2.hist(column='Total Population')
#
# File ~/miniconda3/envs/PLCY_698_DATA_ANALYSIS/lib/python3.10/site-packages/pandas/plotting/_core.py:231, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     140 """
#     141 Make a histogram of the DataFrame's columns.
#     142
#    (...)
#     228     >>> hist = df.hist(bins=3)
#     229 """
#     230 plot_backend = _get_plot_backend(backend)
# --> 231 return plot_backend.hist_frame(
#     232     data,
#     233     column=column,
#     234     by=by,
#     235     grid=grid,
#     236     xlabelsize=xlabelsize,
#     237     xrot=xrot,
#     238     ylabelsize=ylabelsize,
#     239     yrot=yrot,
#     240     ax=ax,
#     241     sharex=sharex,
# ...

# %%
edf_data_2
# Out:
#       Place FIPS  Unincorporated, Non-Place FIPS      Geography Name  \
# 0      3700160.0                             NaN       Aberdeen town
# 2      3700440.0                             NaN         Advance CDP
# 4      3700500.0                             NaN        Ahoskie town
# 6      3700640.0                             NaN    Alamance village
# 8      3700680.0                             NaN      Albemarle city
# ...          ...                             ...                 ...
# 1542   3775880.0                             NaN  Yadkin College CDP
# 1544   3775960.0                             NaN    Yadkinville town
# 1546   3776000.0                             NaN    Yanceyville town
# 1548   3776200.0                             NaN    Youngsville town
# 1550   3776220.0                             NaN        Zebulon town
#
#      County FIPS County Name Total Population  \
# 0            125       Moore            7,862
# ...

# %%
str_to_flt("Under 5 Years")
# Out:
# <class 'numpy.float64'>
# /var/folders/sb/jbh1d71j5c9clmnb_rnsjqb00000gn/T/ipykernel_51716/2816008489.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edf_data_2[column_name] = edf_data_2[column_name].str.replace(',', '')
# /var/folders/sb/jbh1d71j5c9clmnb_rnsjqb00000gn/T/ipykernel_51716/2816008489.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edf_data_2[column_name] = edf_data_2[column_name].astype(float)

# %%
edf_data_2
# Out:
#       Place FIPS  Unincorporated, Non-Place FIPS      Geography Name  \
# 0      3700160.0                             NaN       Aberdeen town
# 2      3700440.0                             NaN         Advance CDP
# 4      3700500.0                             NaN        Ahoskie town
# 6      3700640.0                             NaN    Alamance village
# 8      3700680.0                             NaN      Albemarle city
# ...          ...                             ...                 ...
# 1542   3775880.0                             NaN  Yadkin College CDP
# 1544   3775960.0                             NaN    Yadkinville town
# 1546   3776000.0                             NaN    Yanceyville town
# 1548   3776200.0                             NaN    Youngsville town
# 1550   3776220.0                             NaN        Zebulon town
#
#      County FIPS County Name Total Population  \
# 0            125       Moore            7,862
# ...

# %%
str_to_flt("5 to 9 Years")
str_to_flt("10 to 14 Years")
str_to_flt("15 to 17 Years")
# Out:
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# /var/folders/sb/jbh1d71j5c9clmnb_rnsjqb00000gn/T/ipykernel_51716/2816008489.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edf_data_2[column_name] = edf_data_2[column_name].str.replace(',', '')
# /var/folders/sb/jbh1d71j5c9clmnb_rnsjqb00000gn/T/ipykernel_51716/2816008489.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edf_data_2[column_name] = edf_data_2[column_name].astype(float)

# %%
edf_data_2

# %%
str_to_flt("18 to 24 Years")
str_to_flt("25 to 34 Years")
str_to_flt("35 to 44 Years")
str_to_flt("45 to 54 Years")
str_to_flt("55 to 64 Years")
str_to_flt("65 to 74 Years")
str_to_flt("75 to 84 Years")
str_to_flt("85 Years and Over")
str_to_flt("White Alone")
# Out:
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# /var/folders/sb/jbh1d71j5c9clmnb_rnsjqb00000gn/T/ipykernel_51716/2816008489.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edf_data_2[column_name] = edf_data_2[column_name].str.replace(',', '')
# /var/folders/sb/jbh1d71j5c9clmnb_rnsjqb00000gn/T/ipykernel_51716/2816008489.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# Black or African American Alone is the next column to be converted!

# %%
str_to_flt("Black or African American Alone")
str_to_flt("American Indian and Alaska Native Alone")
str_to_flt("Asian Alone")
str_to_flt("Native Hawaiian and Other Pacific Islander Alone")
# Out:
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# /var/folders/sb/jbh1d71j5c9clmnb_rnsjqb00000gn/T/ipykernel_51716/2816008489.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edf_data_2[column_name] = edf_data_2[column_name].str.replace(',', '')
# /var/folders/sb/jbh1d71j5c9clmnb_rnsjqb00000gn/T/ipykernel_51716/2816008489.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
edf_data_2
# Out:
#       Place FIPS  Unincorporated, Non-Place FIPS      Geography Name  \
# 0      3700160.0                             NaN       Aberdeen town
# 2      3700440.0                             NaN         Advance CDP
# 4      3700500.0                             NaN        Ahoskie town
# 6      3700640.0                             NaN    Alamance village
# 8      3700680.0                             NaN      Albemarle city
# ...          ...                             ...                 ...
# 1542   3775880.0                             NaN  Yadkin College CDP
# 1544   3775960.0                             NaN    Yadkinville town
# 1546   3776000.0                             NaN    Yanceyville town
# 1548   3776200.0                             NaN    Youngsville town
# 1550   3776220.0                             NaN        Zebulon town
#
#      County FIPS County Name Total Population  \
# 0            125       Moore            7,862
# ...

# %%
str_to_flt("Two or More Races")
# Out:
# <class 'numpy.float64'>
# /var/folders/sb/jbh1d71j5c9clmnb_rnsjqb00000gn/T/ipykernel_51716/2816008489.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edf_data_2[column_name] = edf_data_2[column_name].str.replace(',', '')
# /var/folders/sb/jbh1d71j5c9clmnb_rnsjqb00000gn/T/ipykernel_51716/2816008489.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edf_data_2[column_name] = edf_data_2[column_name].astype(float)

# %%
edf_data_2
# Out:
#       Place FIPS  Unincorporated, Non-Place FIPS      Geography Name  \
# 0      3700160.0                             NaN       Aberdeen town
# 2      3700440.0                             NaN         Advance CDP
# 4      3700500.0                             NaN        Ahoskie town
# 6      3700640.0                             NaN    Alamance village
# 8      3700680.0                             NaN      Albemarle city
# ...          ...                             ...                 ...
# 1542   3775880.0                             NaN  Yadkin College CDP
# 1544   3775960.0                             NaN    Yadkinville town
# 1546   3776000.0                             NaN    Yanceyville town
# 1548   3776200.0                             NaN    Youngsville town
# 1550   3776220.0                             NaN        Zebulon town
#
#      County FIPS County Name Total Population  \
# 0            125       Moore            7,862
# ...

# %%
# itirate through all string columns and convert to float
for column in edf_data_2.columns:
    if isinstance(edf_data_2[column][0], str):
        str_to_flt(column)
# Out:
# /var/folders/sb/jbh1d71j5c9clmnb_rnsjqb00000gn/T/ipykernel_52092/2816008489.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edf_data_2[column_name] = edf_data_2[column_name].str.replace(',', '')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       2 for column in edf_data_2.columns:
#       3     if isinstance(edf_data_2[column][0], str):
# ----> 4         str_to_flt(column)
#
# Cell In[6], line 3, in str_to_flt(column_name)
#       1 def str_to_flt(column_name):
#       2     edf_data_2[column_name] = edf_data_2[column_name].str.replace(',', '')
# ...

# %%
# export to csv
edf_data_2.to_csv('EDF_Database_2v3.csv', index=False)

# %%
# get column type
type(edf_data_2['Total Population'][0])
# Out:
# str

# %%
# convert all number columns to float type
for column in edf_data_2.columns:
    if isinstance(edf_data_2[column][0], float):
        edf_data_2[column] = edf_data_2[column].astype(float)
# Out:
# /var/folders/sb/jbh1d71j5c9clmnb_rnsjqb00000gn/T/ipykernel_52092/1184906126.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edf_data_2[column] = edf_data_2[column].astype(float)

# %%
type(edf_data_2['Total Population'][0])
# Out:
# str
